# %%
import pyttsx3
import webbrowser
import smtplib
import random
import speech_recognition as sr
import wikipedia
import datetime
import os
import sys
import math

engine = pyttsx3.init('sapi5')


voices = engine.getProperty('voices')
engine.setProperty('voice', voices[len(voices)-1].id)

#voices = engine.getProperty('voices')
#engine.setProperty('voice', voices[0].id)

master='Manoj'

def speak(audio):
    print('Edith: ' + audio)
    engine.say(audio)
    engine.runAndWait()

def greetMe():
    currentH = int(datetime.datetime.now().hour)
    if currentH >= 0 and currentH < 12:
        speak('Good Morning!')

    if currentH >= 12 and currentH < 16:
        speak('Good Afternoon!')

    if currentH >= 18 and currentH !=0:
        speak('Good Evening!')

greetMe()

speak('Hello' + master)
speak( 'I am your digital assistant edith!')
speak('How may I help you?')


def myCommand():
   
    r = sr.Recognizer()                                                                                   
    with sr.Microphone() as source:                                                                       
        print("Listening...")
        r.pause_threshold =  1
        audio = r.listen(source)
    try:
        query = r.recognize_google(audio, language='en-in')
        print('User: ' + query + '\n')
        
    except sr.UnknownValueError:
        speak('Sorry sir! I didn\'t get that! Try typing the command!')
        query = str(input('Command: '))

    return query
        

if __name__ == '__main__':

    while True:
    
        query = myCommand();
        query = query.lower()
        
        if 'youtube' in query:
            speak('okay, what would you like to watch in youtube?')
            video=myCommand()
            webbrowser.open('https://www.youtube.com/results?search_query=' + video)
            
        elif 'what can you do' in query:
            speak('i can do many things')
            speak('i can search, play music and movies for you, i can also send emails for you and etcetra.')
            speak('Tell me what to do')
            
        elif 'name' in query:
            speak('My name is edith')
        
        elif 'who created you' in query:
            speak('ofcourse its you manoj')
            

        elif 'open google' in query:
            speak('okay, what would you like to search in google')
            search=myCommand()
            webbrowser.open('https://www.google.com/search?hl=en&sxsrf=ACYBGNT_EouywWUVeEdT-2-7mUyoE218PA%3A1579244488857&source=hp&ei=yFshXqCXMZjXz7sPk6-goAo&q=' + search + '&oq=t&gs_l=psy-ab.1.0.35i39l3j0j0i131i67j0l3j0i131j0.130782.130782..133231...3.0..0.196.196.0j1......0....1..gws-wiz.....10..35i362i39.u2lnZpYeM_4&ved=0ahUKEwigm5OWiIrnAhWY63MBHZMXCKQQ4dUDCAo')

        elif 'open gmail' in query:
            speak('okay')
            webbrowser.open('www.gmail.com')

        elif "what\'s up" in query or 'how are you' in query:
            stMsgs = ['Just doing my thing!', 'I am fine!', 'Nice!', 'Nothing much']
            speak(random.choice(stMsgs))
            
        elif 'open a w s' in query:
            speak('okay')
            webbrowser.open('www.aws.com')
                 
        elif 'gold rate' in query:
            speak('in which city, you would like to know?')
            city = myCommand()
            speak('okay! i will show you the gold rate in' + city)
            webbrowser.open('https://www.goodreturns.in/gold-rates/' + city + '.html')          
            
        elif 'weather' in query:
            speak ('in which city, you would like to know?')
            city = myCommand()
            speak('okay! i will show you the weather in' + city)
            webbrowser.open(https://www.theweathernetwork.com/in/weather/andhra-pradesh/v)          

        
        elif 'applications' in query:
            speak('okay! which app you would like to use now')
            app = myCommand()
            speak = ('opening' + app)
            #app_path = 'D:\\apps'
            #apps = ['VLC media player', 'IDMan', 'Visual Studio Code']
            #app = app_path + (apps) + '.exe'
            #os.system(app)
            os.startfile('D:\\apps\\' + app + '.exe')
            
        elif 'my favourite movie' in query:
            speak('okay! Here it is, Enjoy!')
            os.startfile('D:\\Movie collections\\Marvel Cinematic Universe\\Avengers Endgame (2019)\\Avengers.Endgame.2019.2160p.10bit.WEB-DL.6CH.x265.HEVC-PSA.mkv')
                        
        elif 'email' in query:
            speak('Who is the recipient? ')
            recipient = myCommand()
 
           
            if 'me' in recipient:
                try:
                    speak('What should I say? ')
                    content = myCommand()
        
                    server = smtplib.SMTP('smtp.gmail.com', 587)
                    server.ehlo()
                    server.starttls()
                    server.login("Your_Username", 'Your_Password')
                    server.sendmail('Your_Username', "Recipient_Username", content)
                    server.close()
                    speak('Email sent!')

                except:
                    speak('Sorry Sir! I am unable to send your message at this moment!')


        elif 'nothing' in query or 'abort' in query or 'stop' in query:
            speak('okay')
            speak('Bye Sir, have a good day.')
            sys.exit()
           
        elif "hai" in query or 'hello' in query:
            stMsgs = ['Hello Manu', 'Whats up', 'Hey', 'whatcha']
            speak(random.choice(stMsgs))
            response = myCommand()
            
            if 'I am feeling bored' or 'Alone' in response:
                try:
                    speak('oh! would you like to chat with me?')
                    chat = myCommand()
                    
                    if 'yes' in chat:
                        speak('ok! what you have been upto, today?')
                    #mj =     
                    
                        
                    else:
                        speak('ok sir! i am leaving now. i hope you will have a good time today. Bye')
                        sys.exit()
                except:
                    speak('bye sir')
                    sys.exit()

        elif 'bye' in query:
            speak('Bye Sir, have a good day.')
            sys.exit()
                                    
        elif 'play music' in query:
            music_folder = 'C:\\Users\\manoj\\Music\\Music\\'
            music = ['music1', 'music2', 'music3', 'music4', 'music5']
            random_music = music_folder + random.choice(music) + '.mp3'
            os.system(random_music)
                  
            speak('Okay, here is your music! Enjoy!')
        
        elif  'mathematics' in query:
                speak('okay, tell me the numbers and the operator')
                num1 = int(myCommand())
                speak('ok')
                num2 = int(myCommand())
                speak('ok, now tell me the operator')
                calc = myCommand()
                speak('ok')
                
                if 'addition' in calc:
                    ans = num1+num2
                    
                elif 'subtraction' in calc:
                      ans = num1-num2
                
                elif 'division' in calc:
                    ans = num1/num2
                    
                elif 'multiplication' in calc:
                    ans = num1*num2
                
                elif 'power of' in calc:
                    ans = num1**num2
                    
                elif 'modulus' in calc:
                    ans = num1%num2
                
                print(ans)
                speak(ans)
                    
            

        ''''elif 'play movie' in query:
            movie_folder = 'D:\\English mvies\\New folder\\'
            movie = ['Aladdin.2019', 'Pokémon.Detective.Pikachu.2019', 'Toy.Story.4.2019']
            random_movie = movie_folder + random.choice(movie) + '.mkv'
            os.system(random_movie)
                  
            speak('Okay, here is your movie! Enjoy!')'''
            
            
    else:
            query = query
            speak('Searching...')
            try:
                    results = wikipedia.summary(query, sentences=2)
                    speak('Got it.')
                    speak('WIKIPEDIA says - ')
                    speak(results)
        
            except:
                webbrowser.open('www.google.com')
        
            speak('What else! Manoj!')
